# %% [markdown]
# # 큰 수의 법칙

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['font.size'] = 15 
matplotlib.rcParams['axes.unicode_minus'] = False 
import matplotlib.ticker as mticker

# %%
def get_win_rate(size):
    globals()['c{}'.format(size)]=0
    globals()['l{}'.format(size)] = np.random.randint(1,3,size=size)
    for x in range(size):
        if  globals()['l{}'.format(size)][x] == 1:
            globals()['c{}'.format(size)] += 1
        globals()['p{}'.format(size)] = globals()['c{}'.format(size)] / size * 100


def show(size):
    p_list = [50]
    for x in range(1,size+1):
        get_win_rate(x)
        p_list.append(globals()['p{}'.format(x)])
    #print(p_list)
    plt.figure(figsize = (10,6))
    plt.plot(range(0,size+1),p_list,linewidth=10,color='cornflowerblue')
    plt.title('동전 던지기')
    plt.xlabel('시행 횟수')
    plt.ylabel('승률')
    plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d%%'))
    plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))
    plt.ylim(0,105)
    plt.grid(alpha=0.5)
show(50)

# %%
def get_win_rate(size):
    globals()['c{}'.format(size)]=0
    globals()['l{}'.format(size)] = np.random.randint(1,3,size=size)
    for x in range(size):
        if  globals()['l{}'.format(size)][x] == 1:
            globals()['c{}'.format(size)] += 1
        globals()['p{}'.format(size)] = globals()['c{}'.format(size)] / size * 100

def show1(size):
    p_list = [50]
    for x in range(1,size+1):
        get_win_rate(x)
        p_list.append(globals()['p{}'.format(x)])
    #print(p_list)
    plt.figure(figsize = (10,6))
    plt.plot(range(0,size+1),p_list,linewidth=10,color='cornflowerblue')
    plt.title('동전 던지기 (0번~50번)')
    plt.xlabel('시행 횟수')
    plt.ylabel('승률')
    plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d%%'))
    plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))
    plt.ylim(0,105)
    plt.grid(alpha=1)

def show2(size):
    p_list = [50]
    for x in range(1,size+1):
        get_win_rate(x)
        p_list.append(globals()['p{}'.format(x)])
    #print(p_list)
    plt.figure(figsize = (10,6))
    plt.plot(range(size+1),p_list,linewidth=3,color='cornflowerblue')
    plt.title('동전 던지기 (0번~500번)')
    plt.xlabel('시행 횟수')
    plt.ylabel('승률')
    plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d%%'))
    plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))
    plt.ylim(0,105)
    plt.grid(alpha=1)

def show3(size):
    p_list = [50]
    for x in range(1,size+1):
        get_win_rate(x)
        p_list.append(globals()['p{}'.format(x)])
    #print(p_list)
    plt.figure(figsize = (10,6))
    plt.plot(range(50,size+1),p_list[50:],linewidth=1,color='cornflowerblue')
    plt.title('동전 던지기 (50번~3000번)')
    plt.xlabel('시행 횟수')
    plt.ylabel('승률')
    plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d%%'))
    plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))
    plt.ylim(30,70)
    plt.grid(alpha=1)

def show4(size):
    p_list = [50]
    for x in range(1,size+1):
        get_win_rate(x)
        p_list.append(globals()['p{}'.format(x)])
    #print(p_list)
    plt.figure(figsize = (10,6))
    plt.plot(range(50,size+1),p_list[50:],linewidth=0.6,color='cornflowerblue')
    plt.title('동전 던지기 (50번~10000번)')
    plt.xlabel('시행 횟수')
    plt.ylabel('승률')
    plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d%%'))
    plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))
    plt.ylim(30,70)
    plt.grid(alpha=1)


show1(50)
show2(500)
show3(3000)
show4(10000)

# %%
def get_win_rate(size):
    globals()['c{}'.format(size)]=0
    globals()['l{}'.format(size)] = np.random.randint(1,3,size=size)
    for x in range(size):
        if  globals()['l{}'.format(size)][x] == 1:
            globals()['c{}'.format(size)] += 1
        globals()['p{}'.format(size)] = globals()['c{}'.format(size)] / size * 100
    print("{}번 동전 던졌을때의 승률 : {}".format(size,globals()['p{}'.format(size)]))

get_win_rate(10)
get_win_rate(100)
get_win_rate(1000)
get_win_rate(5000)
get_win_rate(10000)
get_win_rate(100000)
# Out:
# 10번 동전 던졌을때의 승률 : 60.0
# 100번 동전 던졌을때의 승률 : 47.0
# 1000번 동전 던졌을때의 승률 : 52.1
# 5000번 동전 던졌을때의 승률 : 50.46000000000001
# 10000번 동전 던졌을때의 승률 : 49.84
# 100000번 동전 던졌을때의 승률 : 50.251999999999995
